# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import json
from collections import Counter
import pyarrow

warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd
import json
import win32com.client

def resolve_shortcut(path):
    """Resuelve un acceso directo de Windows y devuelve la ruta real."""
    shell = win32com.client.Dispatch("WScript.Shell")
    shortcut = shell.CreateShortCut(path)
    return shortcut.Targetpath

def process_directory(directory_path):
    files = os.listdir(directory_path)
    dataframes = []
    
    for file in files:
        if file.endswith('.json'):
            file_path = os.path.join(directory_path, file)
            try:
                df = pd.read_json(file_path, lines=True)
                dataframes.append(df)
            except Exception as e:
                print(f"Error al procesar {file_path}: {e}")
    
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        return combined_df
    else:
        return None

created_dataframes = []

for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        if file.endswith('.lnk'):
            resolved_path = resolve_shortcut(os.path.join(root, file))
            if os.path.isdir(resolved_path):
                dirs.append(resolved_path)  # Agregar la ruta resuelta a la lista de directorios para ser procesada

    for directory in dirs:
        full_directory_path = os.path.join(root, directory)
        df = process_directory(full_directory_path)
        
        if df is not None:
            df.dropna(inplace=True)
            df_name = directory.replace("-", "_")
            globals()[df_name] = df
            created_dataframes.append(df_name)

print("DataFrames creados:")
for name in created_dataframes:
    print(name)
# Out:
# DataFrames creados:
# metadata_sitios
# review_Wyoming
# review_Wisconsin
# review_West_Virginia
# review_Washington
# review_Virginia
# review_Vermont
# review_Utah
# review_Texas
# review_Tennessee
# review_South_Dakota
# review_South_Carolina
# review_Rhode_Island
# review_Pennsylvania
# review_Oregon
# review_Oklahoma
# review_Ohio
# review_North_Dakota
# review_North_Carolina
# review_New_York
# review_New_Mexico
# review_New_Jersey
# review_New_Hampshire
# review_Nevada
# review_Nebraska
# review_Montana
# review_Missouri
# review_Mississippi
# review_Minnesota
# review_Michigan
# review_Massachusetts
# review_Maryland
# review_Maine
# review_Louisiana
# review_Kentucky
# review_Kansas
# review_Iowa
# review_Indiana
# review_Illinois
# review_Idaho
# review_Hawaii
# review_Georgia
# review_Florida
# review_District_of_Columbia
# review_Delaware
# review_Connecticut
# review_Colorado
# review_California
# review_Arkansas
# review_Arizona
# review_Alaska
# review_Alabama

# %%
metadata_sitios
# Out:
#                               name  \
# 29                         Casey's
# 38                        Kum & Go
# 59       Lake Almanor Ace Hardware
# 95                         Casey's
# 117               Ashley HomeStore
# ...                            ...
# 3024967                     Subway
# 3024968                     Subway
# 3024976            Country Kitchen
# 3024981                    Dunkin'
# 3024991                      Munch
#
#                                                    address  \
# 29             Casey's, 901 E Walnut St, Raymore, MO 64083
# 38              Kum & Go, 2091 E Main St, Lamoni, IA 50140
# 59       Lake Almanor Ace Hardware, 417 Main St, Cheste...
# 95            Casey's, 807 S Broadway, Oak Grove, MO 64075
# 117      Ashley HomeStore, 1540 S Main St #120, Blacksb...
# ...                                                    ...
# 3024967  Subway, 6375 Heber Springs Rd W, Quitman, AR 7...
# 3024968     Subway, 525 W Main St, Heber Springs, AR 72543
# 3024976   Country Kitchen, 701 Main St, Pangburn, AR 72121
# 3024981  Dunkin', 7000 Chester Ave, Philadelphia, PA 19142
# 3024991  Munch, 5285 Meadows Rd #188, Lake Oswego, OR 9...
#
#                                        gmap_id  \
# 29        0x87c0d920986abfd3:0x15adec53a9ba23c
# 38       0x87ebd271df3aec61:0xa927d22927807bec
# 59       0x809d6a2364e73caf:0x35bc5133be7c5bf8
# 95       0x87c113b291df1203:0x4967978ec8ba4424
# 117      0x884d95f96d250ced:0xa07c3df0c32c3481
# ...                                        ...
# 3024967  0x87d268933b2e8637:0x7690da2187bb74d9
# 3024968  0x87d246f0f9aa080f:0x5023e31e61a87f1c
# 3024976  0x87d24cd30b7695d1:0xdc25418ff311a6aa
# 3024981  0x89c6c4072624d2a9:0x4437b2d55e9a5811
# 3024991  0x54957330545fc915:0xd14f2cb33733fb2b
#
#                                                description   latitude  \
# 29       Convenience-store chain offering fuel, drinks ...  38.803051
# 38       Gas station & convenience store chain offering...  40.623083
# 59       Chain retailer stocking household tools, suppl...  40.302791
# 95       Convenience-store chain offering fuel, drinks ...  39.009558
# 117      Retail chain with a variety of signature home ...  37.212507
# ...                                                    ...        ...
# 3024967  Casual counter-serve chain for build-your-own ...  35.377148
# 3024968  Casual counter-serve chain for build-your-own ...  35.491484
# 3024976  Homey chain eatery serving breakfast all day &...  35.425678
# 3024981  Long-running chain serving signature breakfast...  39.923594
# 3024991  Deli preparing breakfast, baked goods, sandwic...  45.418568
#
#           longitude                                           category  \
# 29       -94.439582   [Pizza delivery, Convenience store, Gas station]
# 38       -93.896684  [Gas station, ATM, Convenience store, Diesel f...
# 59      -121.234154  [Home improvement store, Building materials su...
# 95       -94.129652   [Pizza delivery, Convenience store, Gas station]
# 117      -80.401185  [Furniture store, Bedroom furniture store, Chi...
# ...             ...                                                ...
# 3024967  -92.223073  [Sandwich shop, Caterer, Fast food restaurant,...
# 3024968  -92.034937  [Sandwich shop, Caterer, Fast food restaurant,...
# 3024976  -91.839200                              [American restaurant]
# 3024981  -75.245269  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 3024991 -122.730475  [Deli, Coffee shop, Takeout Restaurant, Sandwi...
#
#          avg_rating  num_of_reviews price  \
# 29              3.9              78     $
# 38              4.0               8    $$
# 59              4.7              88    $$
# 95              3.6              48     $
# 117             4.2              65    $$
# ...             ...             ...   ...
# 3024967         4.0             124     $
# 3024968         4.2             125     $
# 3024976         4.5              78     $
# 3024981         4.0             348     $
# 3024991         4.6              44     $
#
#                                                      hours  \
# 29       [[Tuesday, 5AM–10PM], [Wednesday, 5AM–10PM], [...
# 38       [[Tuesday, Open 24 hours], [Wednesday, Open 24...
# 59       [[Tuesday, 8:30AM–5PM], [Wednesday, 8:30AM–5PM...
# 95       [[Tuesday, Open 24 hours], [Wednesday, Open 24...
# 117      [[Tuesday, 10AM–7PM], [Wednesday, 10AM–7PM], [...
# ...                                                    ...
# 3024967  [[Monday, 7AM–10PM], [Tuesday, 7AM–10PM], [Wed...
# 3024968  [[Monday, 7AM–9PM], [Tuesday, 7AM–9PM], [Wedne...
# 3024976  [[Monday, 6AM–2PM], [Tuesday, 6AM–2PM], [Wedne...
# 3024981  [[Monday, 5:30AM–7:30PM], [Tuesday, 5:30AM–7:3...
# 3024991  [[Monday, 7:30AM–2PM], [Tuesday, 7:30AM–2PM], ...
#
#                                                       MISC  \
# 29       {'Service options': ['Curbside pickup', 'No-co...
# 38       {'Accessibility': ['Wheelchair accessible entr...
# 59       {'Service options': ['Curbside pickup', 'In-st...
# 95       {'Service options': ['Curbside pickup', 'No-co...
# 117      {'Service options': ['Delivery', 'In-store sho...
# ...                                                    ...
# 3024967  {'Service options': ['Outdoor seating', 'Drive...
# 3024968  {'Service options': ['Curbside pickup', 'Takeo...
# 3024976  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3024981  {'Service options': ['Delivery', 'Drive-throug...
# 3024991  {'From the business': ['Identifies as women-le...
#
#                          state  \
# 29          Open ⋅ Closes 10PM
# 38               Open 24 hours
# 59       Closed ⋅ Opens 8:30AM
# 95               Open 24 hours
# 117          Opens soon ⋅ 10AM
# ...                        ...
# 3024967     Open ⋅ Closes 10PM
# 3024968      Open ⋅ Closes 9PM
# 3024976      Open ⋅ Closes 2PM
# 3024981   Open ⋅ Closes 7:30PM
# 3024991      Open ⋅ Closes 2PM
#
#                                           relative_results  \
# 29       [0x87c0d94efc2ff60b:0x71c18bc2278f0240, 0x87c0...
# 38       [0x87ebcdbdd51b7def:0xa7fe7b002839522a, 0x87eb...
# 59       [0x809d6a237b7acb63:0x178eb328a18cc196, 0x809d...
# 95       [0x87c11394846dd0e7:0x96832567302db6b5, 0x87c1...
# 117      [0x884d937daf179023:0x72aefbd934d77b64, 0x884d...
# ...                                                    ...
# 3024967  [0x87d268accba2b793:0x741284bb3aee7b1b, 0x87d2...
# 3024968  [0x87d24401659a1fb7:0x7907d995b6f47c22, 0x87d2...
# 3024976  [0x87d24cd14c2328ff:0x42797c7e42cd07ba, 0x87d2...
# 3024981  [0x89c6c6d16baf5e31:0x85b50cbaee46e6fb, 0x89c6...
# 3024991  [0x5495732e6d386309:0x548e43dc6b69707e, 0x5495...
#
#                                                        url
# 29       https://www.google.com/maps/place//data=!4m2!3...
# 38       https://www.google.com/maps/place//data=!4m2!3...
# 59       https://www.google.com/maps/place//data=!4m2!3...
# 95       https://www.google.com/maps/place//data=!4m2!3...
# 117      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 3024967  https://www.google.com/maps/place//data=!4m2!3...
# 3024968  https://www.google.com/maps/place//data=!4m2!3...
# 3024976  https://www.google.com/maps/place//data=!4m2!3...
# 3024981  https://www.google.com/maps/place//data=!4m2!3...
# 3024991  https://www.google.com/maps/place//data=!4m2!3...
#
# [136693 rows x 15 columns]

# %% [markdown]
# Crear una nueva columna con las abreviaturas de los estados en metadata_sitios

# %%
metadata_sitios['states'] = metadata_sitios['address'].str.rsplit().str[-2]

# Filtrar las filas donde la longitud de la columna 'state' no es igual a 2 caracteres
condition = ~metadata_sitios['states'].str.match(r'^[A-Za-z]{2}$')
metadata_sitios.drop(metadata_sitios[condition].index, inplace=True)
metadata_sitios["states"].unique()
# Out:
# array(['MO', 'IA', 'CA', 'VA', 'NJ', 'PA', 'WV', 'OH', 'GA', 'IN', 'NC',
#        'TX', 'SC', 'CO', 'SD', 'WA', 'OK', 'MA', 'NY', 'TN', 'FL', 'KS',
#        'AZ', 'CT', 'MN', 'NV', 'RI', 'AL', 'MD', 'DE', 'UT', 'DC', 'IL',
#        'MI', 'LA', 'OR', 'KY', 'WI', 'NM', 'MS', 'ME', 'ND', 'NE', 'ID',
#        'MT', 'AR', 'WY', 'HI', 'NH', 'VT', 'AK'], dtype=object)

# %%
metadata_sitios
# Out:
#                             name                                gmap_id  \
# 829       Charleys Philly Steaks  0x89c2fad0e50bf7cb:0x54444ad44d42f751
# 840       Charleys Philly Steaks  0x89c3953fd908dfdd:0xdd16fbfbd5c00287
# 4771                        Wawa  0x89c6d1b9c859e8d3:0x31cd6538a59b1652
# 5335                        Wawa  0x89c14e8ce3a3ef95:0x461d98ec6a8cc8dc
# 15094                       Wawa  0x89c6ba967620488d:0x374d5c9f7d30477d
# ...                          ...                                    ...
# 3020816   Charleys Philly Steaks  0x80c2c0f8b7ce26a7:0xa1c1bc95a9edf755
# 3021898  Philadelphia Sandwiches   0x80c295f3993509dd:0xe06eb565627d293
# 3022128                     Wawa   0x88deeae0bd419e63:0xa8fc8129a2a89c0
# 3022597                     Wawa  0x89c107d07784f701:0x273e5f817bd0afa6
# 3024069    Charleys Cheesesteaks  0x8631320ddbe47d87:0x66f52a11b0303706
#
#           latitude   longitude  \
# 829      40.956903  -74.069185
# 840      40.585621  -74.618851
# 4771     39.806306  -75.094958
# 5335     40.072781  -74.850274
# 15094    40.139008  -75.172080
# ...            ...         ...
# 3020816  34.144814 -118.259133
# 3021898  34.164790 -118.372946
# 3022128  27.263900  -80.431880
# 3022597  39.708065  -74.253232
# 3024069  32.493650  -93.676310
#
#                                                   category  avg_rating  \
# 829      [Cheesesteak restaurant, American restaurant, ...         4.0
# 840      [Cheesesteak restaurant, American restaurant, ...         3.7
# 4771     [Convenience store, Breakfast restaurant, Cafe...         4.2
# 5335     [Convenience store, Breakfast restaurant, Cafe...         3.8
# 15094    [Convenience store, Breakfast restaurant, Cafe...         4.5
# ...                                                    ...         ...
# 3020816  [Cheesesteak restaurant, American restaurant, ...         4.1
# 3021898            [Cheesesteak restaurant, Sandwich shop]         3.9
# 3022128  [Convenience store, Breakfast restaurant, Cafe...         4.3
# 3022597  [Convenience store, Breakfast restaurant, Cafe...         4.3
# 3024069  [Cheesesteak restaurant, American restaurant, ...         4.0
#
#          num_of_reviews                                                url  \
# 829                  18  https://www.google.com/maps/place//data=!4m2!3...
# 840                  36  https://www.google.com/maps/place//data=!4m2!3...
# 4771                 78  https://www.google.com/maps/place//data=!4m2!3...
# 5335                138  https://www.google.com/maps/place//data=!4m2!3...
# 15094                98  https://www.google.com/maps/place//data=!4m2!3...
# ...                 ...                                                ...
# 3020816              35  https://www.google.com/maps/place//data=!4m2!3...
# 3021898              28  https://www.google.com/maps/place//data=!4m2!3...
# 3022128             178  https://www.google.com/maps/place//data=!4m2!3...
# 3022597              38  https://www.google.com/maps/place//data=!4m2!3...
# 3024069              58  https://www.google.com/maps/place//data=!4m2!3...
#
#         states
# 829         NJ
# 840         NJ
# 4771        NJ
# 5335        NJ
# 15094       PA
# ...        ...
# 3020816     CA
# 3021898     CA
# 3022128     FL
# 3022597     NJ
# 3024069     LA
#
# [532 rows x 9 columns]

# %% [markdown]
# Filtrado por los estados elejidos 'PA' 'IL' 'DE' 'AZ' 'MO' 'NJ' 'FL' 'NV' 'CA' 'IN' 'TN' 'ID' 'LA'

# %%
# Lista de estados deseados
estados_elegidos = ['PA', 'IL', 'DE', 'AZ', 'MO', 'NJ', 'FL', 'NV', 'CA', 'IN', 'TN', 'ID', 'LA']

# Filtrar el DataFrame
metadata_sitios = metadata_sitios[metadata_sitios['states'].isin(estados_elegidos)]

# %% [markdown]
# Columnas a eliminar address, description, price, hours, MISC, state, relative_results

# %%
columns_to_drop = ['address', 'description', 'price', 'hours', 'MISC', 'state', 'relative_results']

metadata_sitios.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# Filtrado por categoria

# %%
metadata_sitios = metadata_sitios[metadata_sitios['category'].apply(lambda x: any('steak house' in word.lower() or 'steak' in word.lower() or 'bistec' in word.lower() or 'beef' in word.lower() for word in x) if isinstance(x, list) else False)]

# %%
metadata_sitios
# Out:
#                             name                                gmap_id  \
# 829       Charleys Philly Steaks  0x89c2fad0e50bf7cb:0x54444ad44d42f751
# 840       Charleys Philly Steaks  0x89c3953fd908dfdd:0xdd16fbfbd5c00287
# 4771                        Wawa  0x89c6d1b9c859e8d3:0x31cd6538a59b1652
# 5335                        Wawa  0x89c14e8ce3a3ef95:0x461d98ec6a8cc8dc
# 15094                       Wawa  0x89c6ba967620488d:0x374d5c9f7d30477d
# ...                          ...                                    ...
# 3020816   Charleys Philly Steaks  0x80c2c0f8b7ce26a7:0xa1c1bc95a9edf755
# 3021898  Philadelphia Sandwiches   0x80c295f3993509dd:0xe06eb565627d293
# 3022128                     Wawa   0x88deeae0bd419e63:0xa8fc8129a2a89c0
# 3022597                     Wawa  0x89c107d07784f701:0x273e5f817bd0afa6
# 3024069    Charleys Cheesesteaks  0x8631320ddbe47d87:0x66f52a11b0303706
#
#           latitude   longitude  \
# 829      40.956903  -74.069185
# 840      40.585621  -74.618851
# 4771     39.806306  -75.094958
# 5335     40.072781  -74.850274
# 15094    40.139008  -75.172080
# ...            ...         ...
# 3020816  34.144814 -118.259133
# 3021898  34.164790 -118.372946
# 3022128  27.263900  -80.431880
# 3022597  39.708065  -74.253232
# 3024069  32.493650  -93.676310
#
#                                                   category  avg_rating  \
# 829      [Cheesesteak restaurant, American restaurant, ...         4.0
# 840      [Cheesesteak restaurant, American restaurant, ...         3.7
# 4771     [Convenience store, Breakfast restaurant, Cafe...         4.2
# 5335     [Convenience store, Breakfast restaurant, Cafe...         3.8
# 15094    [Convenience store, Breakfast restaurant, Cafe...         4.5
# ...                                                    ...         ...
# 3020816  [Cheesesteak restaurant, American restaurant, ...         4.1
# 3021898            [Cheesesteak restaurant, Sandwich shop]         3.9
# 3022128  [Convenience store, Breakfast restaurant, Cafe...         4.3
# 3022597  [Convenience store, Breakfast restaurant, Cafe...         4.3
# 3024069  [Cheesesteak restaurant, American restaurant, ...         4.0
#
#          num_of_reviews                                                url  \
# 829                  18  https://www.google.com/maps/place//data=!4m2!3...
# 840                  36  https://www.google.com/maps/place//data=!4m2!3...
# 4771                 78  https://www.google.com/maps/place//data=!4m2!3...
# 5335                138  https://www.google.com/maps/place//data=!4m2!3...
# 15094                98  https://www.google.com/maps/place//data=!4m2!3...
# ...                 ...                                                ...
# 3020816              35  https://www.google.com/maps/place//data=!4m2!3...
# 3021898              28  https://www.google.com/maps/place//data=!4m2!3...
# 3022128             178  https://www.google.com/maps/place//data=!4m2!3...
# 3022597              38  https://www.google.com/maps/place//data=!4m2!3...
# 3024069              58  https://www.google.com/maps/place//data=!4m2!3...
#
#         states
# 829         NJ
# 840         NJ
# 4771        NJ
# 5335        NJ
# 15094       PA
# ...        ...
# 3020816     CA
# 3021898     CA
# 3022128     FL
# 3022597     NJ
# 3024069     LA
#
# [528 rows x 9 columns]

# %% [markdown]
# Eliminar duplicados

# %%
# Convertir las columnas que contienen listas a cadenas
for col in metadata_sitios.columns:
    if metadata_sitios[col].apply(type).eq(list).any():
        metadata_sitios[col] = metadata_sitios[col].astype(str)

# Eliminar filas duplicadas
metadata_sitios = metadata_sitios.drop_duplicates()

# Convertir las columnas que contienen cadenas de listas de nuevo a listas
for col in metadata_sitios.columns:
    if metadata_sitios[col].apply(type).eq(str).any():
        try:
            metadata_sitios[col] = metadata_sitios[col].apply(eval)
        except:
            pass

# %%
metadata_sitios
# Out:
#                             name                                gmap_id  \
# 829       Charleys Philly Steaks  0x89c2fad0e50bf7cb:0x54444ad44d42f751
# 840       Charleys Philly Steaks  0x89c3953fd908dfdd:0xdd16fbfbd5c00287
# 4771                        Wawa  0x89c6d1b9c859e8d3:0x31cd6538a59b1652
# 5335                        Wawa  0x89c14e8ce3a3ef95:0x461d98ec6a8cc8dc
# 15094                       Wawa  0x89c6ba967620488d:0x374d5c9f7d30477d
# ...                          ...                                    ...
# 3020816   Charleys Philly Steaks  0x80c2c0f8b7ce26a7:0xa1c1bc95a9edf755
# 3021898  Philadelphia Sandwiches   0x80c295f3993509dd:0xe06eb565627d293
# 3022128                     Wawa   0x88deeae0bd419e63:0xa8fc8129a2a89c0
# 3022597                     Wawa  0x89c107d07784f701:0x273e5f817bd0afa6
# 3024069    Charleys Cheesesteaks  0x8631320ddbe47d87:0x66f52a11b0303706
#
#           latitude   longitude  \
# 829      40.956903  -74.069185
# 840      40.585621  -74.618851
# 4771     39.806306  -75.094958
# 5335     40.072781  -74.850274
# 15094    40.139008  -75.172080
# ...            ...         ...
# 3020816  34.144814 -118.259133
# 3021898  34.164790 -118.372946
# 3022128  27.263900  -80.431880
# 3022597  39.708065  -74.253232
# 3024069  32.493650  -93.676310
#
#                                                   category  avg_rating  \
# 829      [Cheesesteak restaurant, American restaurant, ...         4.0
# 840      [Cheesesteak restaurant, American restaurant, ...         3.7
# 4771     [Convenience store, Breakfast restaurant, Cafe...         4.2
# 5335     [Convenience store, Breakfast restaurant, Cafe...         3.8
# 15094    [Convenience store, Breakfast restaurant, Cafe...         4.5
# ...                                                    ...         ...
# 3020816  [Cheesesteak restaurant, American restaurant, ...         4.1
# 3021898            [Cheesesteak restaurant, Sandwich shop]         3.9
# 3022128  [Convenience store, Breakfast restaurant, Cafe...         4.3
# 3022597  [Convenience store, Breakfast restaurant, Cafe...         4.3
# 3024069  [Cheesesteak restaurant, American restaurant, ...         4.0
#
#          num_of_reviews                                                url  \
# 829                  18  https://www.google.com/maps/place//data=!4m2!3...
# 840                  36  https://www.google.com/maps/place//data=!4m2!3...
# 4771                 78  https://www.google.com/maps/place//data=!4m2!3...
# 5335                138  https://www.google.com/maps/place//data=!4m2!3...
# 15094                98  https://www.google.com/maps/place//data=!4m2!3...
# ...                 ...                                                ...
# 3020816              35  https://www.google.com/maps/place//data=!4m2!3...
# 3021898              28  https://www.google.com/maps/place//data=!4m2!3...
# 3022128             178  https://www.google.com/maps/place//data=!4m2!3...
# 3022597              38  https://www.google.com/maps/place//data=!4m2!3...
# 3024069              58  https://www.google.com/maps/place//data=!4m2!3...
#
#         states
# 829         NJ
# 840         NJ
# 4771        NJ
# 5335        NJ
# 15094       PA
# ...        ...
# 3020816     CA
# 3021898     CA
# 3022128     FL
# 3022597     NJ
# 3024069     LA
#
# [528 rows x 9 columns]

# %% [markdown]
# ## Realizamos el ETL en los reviews de los estados seleccionados
# Pensilvania (PA), Illinois (IL), Delaware (DE), Arizona (AZ), Misuri (MO), New Jersey (NJ), Florida (FL), Nevada (NV), California (CA), Indiana (IN), Tennessee (TN), Idaho (ID), Luisiana (LA)

# %%
# Unimos los dataset de los estados selaccionados en uno solo

estados = (review_Pennsylvania, review_Illinois, review_Delaware, review_Arizona, review_Missouri, review_New_Jersey, review_Florida, review_Nevada, review_California, review_Indiana, review_Tennessee, review_Idaho, review_Louisiana)

reviews_estados = pd.concat(estados)

# %%
reviews_estados
# Out:
#               user_id               name           time  rating  \
# 1461     1.136443e+20        Megan Jones  1555025113878       5
# 1463     1.074407e+20   Sydni Berkihiser  1530679850062       5
# 2960     1.011033e+20           McKala O  1575938439855       5
# 3879     1.122548e+20      Melissa Kelly  1614956600429       5
# 3884     1.104853e+20     Armin Fernando  1614534711882       5
# ...               ...                ...            ...     ...
# 1497896  1.127212e+20  Jacqueline Patton  1480439481132       5
# 1498001  1.013891e+20  Denise N Robinson  1492710249991       5
# 1498501  1.085257e+20        Mark Martin  1534354827877       4
# 1499098  1.085726e+20            Kathy D  1621598838718       4
# 1499988  1.156984e+20       Liseth Reyes  1552195413390       5
#
#                                                       text  \
# 1461     We love Dr Arnold and the staff at Willow Run....
# 1463     Great veterinarians and techs. I know my pets ...
# 2960     After being denied the request to test drive a...
# 3879     Hi-Pot was recommended by a friend so I decide...
# 3884     Leisurely Sunday drive to the Poconos Mountain...
# ...                                                    ...
# 1497896    Very friendly and knowledgeable. They are great
# 1498001  Very tasty and very quick service! They warn y...
# 1498501  Three and a half stars. The windows are good q...
# 1499098  Delicious cakes. First time trying. Chose 3 sm...
# 1499988  Love coming here. Always satisfied with their ...
#
#                                                       pics  \
# 1461     [{'url': ['https://lh5.googleusercontent.com/p...
# 1463     [{'url': ['https://lh5.googleusercontent.com/p...
# 2960     [{'url': ['https://lh5.googleusercontent.com/p...
# 3879     [{'url': ['https://lh5.googleusercontent.com/p...
# 3884     [{'url': ['https://lh5.googleusercontent.com/p...
# ...                                                    ...
# 1497896  [{'url': ['https://lh5.googleusercontent.com/p...
# 1498001  [{'url': ['https://lh5.googleusercontent.com/p...
# 1498501  [{'url': ['https://lh5.googleusercontent.com/p...
# 1499098  [{'url': ['https://lh5.googleusercontent.com/p...
# 1499988  [{'url': ['https://lh5.googleusercontent.com/p...
#
#                                                       resp  \
# 1461     {'time': 1559825541880, 'text': 'Good Morning ...
# 1463     {'time': 1531327030102, 'text': 'Thank you so ...
# 2960     {'time': 1575904595288, 'text': 'Kala,
# Thank y...
# 3879     {'time': 1614999289681, 'text': 'Thank you for...
# 3884     {'time': 1614637712283, 'text': 'Thank you for...
# ...                                                    ...
# 1497896  {'time': 1490642500136, 'text': 'Thanks so muc...
# 1498001  {'time': 1494358408814, 'text': 'Hi Denise, we...
# 1498501  {'time': 1534449247235, 'text': 'Hi Mark, Than...
# 1499098  {'time': 1621876535880, 'text': 'We love it, K...
# 1499988          {'time': 1553259751949, 'text': 'Thanks'}
#
#                                        gmap_id
# 1461     0x89c63ab2fe85351f:0x868b040272d5ffea
# 1463     0x89c63ab2fe85351f:0x868b040272d5ffea
# 2960     0x89c68fb173ee2c15:0x4f95004d5e45a232
# 3879     0x89c43f25efcec187:0xd94a7454157d00da
# 3884     0x89c43f25efcec187:0xd94a7454157d00da
# ...                                        ...
# 1497896  0x8636d379d880cab5:0xf28cd60c259db173
# 1498001  0x86312d242e3b5f83:0xcbdf21ac546411c1
# 1498501  0x8620b0cccf1be5a1:0x5997413bccd71719
# 1499098  0x8620a45480744957:0x3808509558573af7
# 1499988  0x8620a4bb99e10559:0xef24f1cc1e9ce8d8
#
# [108305 rows x 8 columns]

# %%
# Columnas a eliminar name, resp

columnas = ['name','resp']

reviews_estados.drop(columns=columnas, inplace=True)

# %%
# Convertir las columnas que contienen listas a cadenas
for col in reviews_estados.columns:
    if reviews_estados[col].apply(type).eq(list).any():
        reviews_estados[col] = reviews_estados[col].astype(str)

# Eliminar filas duplicadas
reviews_estados = reviews_estados.drop_duplicates()

# Convertir las columnas que contienen cadenas de listas de nuevo a listas
for col in reviews_estados.columns:
    if reviews_estados[col].apply(type).eq(str).any():
        try:
            reviews_estados[col] = reviews_estados[col].apply(eval)
        except:
            pass

# %%
reviews_estados
# Out:
#               user_id           time  rating  \
# 1461     1.136443e+20  1555025113878       5
# 1463     1.074407e+20  1530679850062       5
# 2960     1.011033e+20  1575938439855       5
# 3879     1.122548e+20  1614956600429       5
# 3884     1.104853e+20  1614534711882       5
# ...               ...            ...     ...
# 1497896  1.127212e+20  1480439481132       5
# 1498001  1.013891e+20  1492710249991       5
# 1498501  1.085257e+20  1534354827877       4
# 1499098  1.085726e+20  1621598838718       4
# 1499988  1.156984e+20  1552195413390       5
#
#                                                       text  \
# 1461     We love Dr Arnold and the staff at Willow Run....
# 1463     Great veterinarians and techs. I know my pets ...
# 2960     After being denied the request to test drive a...
# 3879     Hi-Pot was recommended by a friend so I decide...
# 3884     Leisurely Sunday drive to the Poconos Mountain...
# ...                                                    ...
# 1497896    Very friendly and knowledgeable. They are great
# 1498001  Very tasty and very quick service! They warn y...
# 1498501  Three and a half stars. The windows are good q...
# 1499098  Delicious cakes. First time trying. Chose 3 sm...
# 1499988  Love coming here. Always satisfied with their ...
#
#                                                       pics  \
# 1461     [{'url': ['https://lh5.googleusercontent.com/p...
# 1463     [{'url': ['https://lh5.googleusercontent.com/p...
# 2960     [{'url': ['https://lh5.googleusercontent.com/p...
# 3879     [{'url': ['https://lh5.googleusercontent.com/p...
# 3884     [{'url': ['https://lh5.googleusercontent.com/p...
# ...                                                    ...
# 1497896  [{'url': ['https://lh5.googleusercontent.com/p...
# 1498001  [{'url': ['https://lh5.googleusercontent.com/p...
# 1498501  [{'url': ['https://lh5.googleusercontent.com/p...
# 1499098  [{'url': ['https://lh5.googleusercontent.com/p...
# 1499988  [{'url': ['https://lh5.googleusercontent.com/p...
#
#                                        gmap_id
# 1461     0x89c63ab2fe85351f:0x868b040272d5ffea
# 1463     0x89c63ab2fe85351f:0x868b040272d5ffea
# 2960     0x89c68fb173ee2c15:0x4f95004d5e45a232
# 3879     0x89c43f25efcec187:0xd94a7454157d00da
# 3884     0x89c43f25efcec187:0xd94a7454157d00da
# ...                                        ...
# 1497896  0x8636d379d880cab5:0xf28cd60c259db173
# 1498001  0x86312d242e3b5f83:0xcbdf21ac546411c1
# 1498501  0x8620b0cccf1be5a1:0x5997413bccd71719
# 1499098  0x8620a45480744957:0x3808509558573af7
# 1499988  0x8620a4bb99e10559:0xef24f1cc1e9ce8d8
#
# [103329 rows x 6 columns]

# %%
# Guardar reviews_estados en formato Parquet
reviews_estados.to_parquet('reviews_estados.parquet')

# Guardar metadata_sitios en formato Parquet
metadata_sitios.to_parquet('metadata_sitios.parquet')
